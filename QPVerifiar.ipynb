# %%
from quantumNN import *
import pandas as pd
import seaborn as sns
import numpy as np
import statistics
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

# %%
q1 = randomQubitState(2)
l1 = randomQubitState(2)

# %%
ntwk = randomcholoNetwork([2,2,2], [q1], [l1])

# %%
plotlist121,Unitaries,Out_States  = qnnTraining(ntwk[0], ntwk[1], ntwk[2], 1, 0.1, 500, 0.999)

for i in range(len(plotlist121[1])):
    if plotlist121[1][i] >= 0.95:
        print("Exceeds cost of 0.95 at training step "+str(i))
        break

plt.plot(plotlist121[0], plotlist121[1])
plt.xlabel("s")
plt.ylabel("Cost[s]")
plt.show()
# Out:
# Exceeds cost of 0.95 at training step 14

# %%
probs = pen_test(1000, 2, [2,2,2], Unitaries, l1)
sns.displot(probs, kde=True)
# Out:
# /home/guby/.local/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Probability of a false positive', ylabel='Density'>

# %%
q1 = randomQubitState(1)
l1 = randomQubitState(1)
ntwk = randomcholoNetwork([1,1,1], [q1], [l1])
plotlist1,Unitaries,Out_States  = qnnTraining(ntwk[0], ntwk[1], ntwk[2], 1, 0.1, 500, 0.999)
probs1 = pen_test(1000, 1, [1,1,1], Unitaries, l1)
sns.displot(probs1, kde=True)

# %%
q2 = randomQubitState(2)
l2 = randomQubitState(2)
ntwk = randomcholoNetwork([2,2,2], [q2], [l2])
plotlist2,Unitaries,Out_States  = qnnTraining(ntwk[0], ntwk[1], ntwk[2], 1, 0.1, 500, 0.999)
probs2 = pen_test(1000, 2, [2,2,2], Unitaries, l2)
sns.displot(probs2, kde=True)

# %%
q3 = randomQubitState(3)
l3 = randomQubitState(3)
ntwk = randomcholoNetwork([3,3,3], [q3], [l3])
plotlist3,Unitaries,Out_States  = qnnTraining(ntwk[0], ntwk[1], ntwk[2], 1, 0.1, 500, 0.999)
probs3 = pen_test(1000, 3, [3,3,3], Unitaries, l3)
sns.displot(probs3, kde=True)

# %%
q4 = randomQubitState(4)
l4 = randomQubitState(4)
ntwk = randomcholoNetwork([4,4,4], [q4], [l4])
plotlist4,Unitaries,Out_States  = qnnTraining(ntwk[0], ntwk[1], ntwk[2], 1, 0.1, 500, 0.999)
probs4 = pen_test(1000, 4, [4,4,4], Unitaries, l4)
sns.displot(probs4, kde=True)
# Out:
# Trained 500 rounds for a [4, 4, 4] network and 1 training pairs in 651.16 seconds

# %%
q5 = randomQubitState(5)
l5 = randomQubitState(5)
ntwk = randomcholoNetwork([5,5,5], [q5], [l5])
plotlist5,Unitaries,Out_States  = qnnTraining(ntwk[0], ntwk[1], ntwk[2], 1, 0.1, 500, 0.999)
probs5 = pen_test(1000, 5, [5,5,5], Unitaries, l5)
sns.displot(probs5, kde=True)
# Out:
# Trained 500 rounds for a [5, 5, 5] network and 1 training pairs in 13244.8 seconds

# %%
import statistics
import numpy as np
mu = statistics.median(probs5)
print(mu)
std = np.std(probs5)
print(std)
# Out:
# 0.6415050004905347
# 0.02917138773647266

# %%
sigma = std
x = np.linspace(mu - 6*sigma, mu + 6*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
sns.displot(probs5, kde=True, stat='density')

# %%
mu = statistics.median(probs4)
print(mu)
std = np.std(probs4)
print(std)
# Out:
# 0.44055924276924724
# 0.0624441759669336

# %%
mu = statistics.median(probs3)
print(mu)
std = np.std(probs3)
print(std)
# Out:
# 0.31368416669037036
# 0.09358411033668451

# %%
mu = statistics.median(probs2)
print(mu)
std = np.std(probs2)
print(std)
# Out:
# 0.45211084918838207
# 0.172641183006456

# %%
mu = statistics.median(probs1)
print(mu)
std = np.std(probs1)
print(std)
# Out:
# 0.8452977834460607
# 0.09065225749945102
